# %%
import numpy as np
import gempy as gp
import pandas as pd
import gempy as gp
import gempy_viewer as gpv
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import rasterio
import os
import pyvista as pv

import geomodel_toolbox
import importlib

importlib.reload(geomodel_toolbox)

# %% [markdown]
# 1. Import stratigraphical model

# %% [markdown]
# 2. Generate randomized fracture models

# %% [markdown]
# 3. Combine stratigraphical and fracture models
